# %%
import pandas as pd
from Top2Vec_Model import Top2Vec_Model

# %%
df = pd.read_csv("../data/processed_reviews.csv")
top2vec_model = Top2Vec_Model(df)

# %%
subcategories=['WIPES DISINFECTING WIPES', 'BODY CARE BODY LOTION', 'AIR FRESHENER', 'SPRAY CLEANERS BLEACH CLEANERS', 'HAIR CARE']
result_df = top2vec_model.train_model(subcategories)
# Out:
# c:\Users\14015\OneDrive\Documents\BTT\Clorox_Company\NEW_REPO\BTT-Clorox-Company\TopicModel\Top2Vec_Model.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['top2vec_topic_number'] = -1
# c:\Users\14015\OneDrive\Documents\BTT\Clorox_Company\NEW_REPO\BTT-Clorox-Company\TopicModel\Top2Vec_Model.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['top2vec_topic_words'] = ''
# ...

# %%
top2vec_model.df.to_csv("FINAL_TOP2VEC_MODEL_RESULTS.csv", index=False)
