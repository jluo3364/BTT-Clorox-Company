# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF
import pandas as pd
from sklearn.preprocessing import normalize
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv("../data/clorox_data.csv")

# %%
df['subcategory'].value_counts().tail(50)
# Out:
# subcategory
# WOOD/FURNITURE/DUST WOOD/FURNITURE CLEANER        1592
# HAIR CARE                                         1591
# WOOD/FURNITURE/DUST POLISH                        1530
# BATHROOM CLEANERS LIMESCALE/HARDWATER CLEANERS    1482
# WOOD/FURNITURE/DUST CONVENIENCE WOOD/FURN/DUST    1447
# CONSUMABLE TOOLS SOAP PADS/STEEL WOOL             1435
# SUNCARE & FIRST AID SUNCARE                       1406
# HAIR CARE SHAMPOO                                 1110
# CORE GIFTS EVERYDAY KITS                          1035
# WIPES OTHER WIPES                                 1033
# LIP CARE                                          1028
# FLOOR CLEANERS                                    1028
# HAIR CARE CONDITIONER                              990
# BODY CARE BATH SOAP                                903
# MEN'S CARE BODY WASH                               895
# ODOR CONTROLLING FABRIC REFRESHERS                 823
# MOISTURE ABSORBER                                  822
# TOILET BOWL CLEANERS                               813
# CONSUMABLE TOOLS                                   637
# BODY CARE FOOT CARE                                631
# WIPES                                              578
# MEN'S CARE FACIAL CLEANSERS                        491
# CORE GIFTS HOLIDAY KITS                            490
# SUNCARE & FIRST AID AFTER SUN                      473
# BATHROOM CLEANERS DAILY SHOWER CLEANERS            440
# SPRAY CLEANERS                                     435
# DILUTABLES                                         386
# BODY CARE DEODORANT                                347
# MEN'S CARE BEARD TREATMENT                         277
# WIPES NATURAL WIPES                                272
# ODOR CONTROLLING AIR ODOR REMOVERS                 230
# MEN'S CARE FACIAL MOISTURIZER & AFTERSHAVE         215
# LIP CARE LIP BUTTERS                               182
# CONSUMABLE TOOLS CLEANING CLOTHS                   120
# BODY CARE BODY WIPES                               111
# WOOD/FURNITURE/DUST FURNITURE WIPES                 97
# WIPES COMPOSTABLE WIPES                             93
# WOOD/FURNITURE/DUST                                 93
# FACE CARE FACE CARE TOOLS                           91
# BATHROOM CLEANERS                                   67
# BODY CARE BODY TOOLS                                62
# SUNCARE & FIRST AID FIRST AID OINTMENT              59
# MEN'S CARE SHAVE                                    58
# FACE CARE HAIR REMOVAL                              54
# SUNCARE & FIRST AID                                 46
# ODOR CONTROLLING                                    27
# DISH CARE LIQUID DISH DETERGENT                     14
# LIP CARE LIP OILS                                    7
# CORE GIFTS                                           5
# BODY CARE HAIR REMOVAL                               1
# Name: count, dtype: int64

# %%
# look at hair care subcategory (1591 values)
df_sample = df[df['subcategory']=='HAIR CARE']
df_sample
# Out:
#                    brand                                      product_title  \
# 214354            Nexxus  Nexxus Advanced Therappe Shampoo and Humectres...
# 214364            Nexxus  Nexxus Advanced Therappe Shampoo and Humectres...
# 214655  Head & Shoulders  Head & Shoulders Complete Scalp Care 2-in-1 Da...
# 214659            Nexxus  Nexxus Advanced Therappe Shampoo and Humectres...
# 214662            Nexxus  Nexxus Advanced Therappe Shampoo and Humectres...
# ...                  ...                                                ...
# 642758        CVS Health             CVS Health Hair Detangling Spray, 10oz
# 646780     Amazon Basics  Amazon Basics 2-in-1 Dandruff Shampoo and Cond...
# 656828     Amazon Basics  Amazon Basics 2-in-1 Dandruff Shampoo and Cond...
# 661227        CVS Health             CVS Health Hair Detangling Spray, 10oz
# 669513        CVS Health             CVS Health Hair Detangling Spray, 10oz
#
#         proxy_date retailer       category subcategory  \
# 214354  2024-07-01   Costco  PERSONAL CARE   HAIR CARE
# 214364  2024-07-01   Costco  PERSONAL CARE   HAIR CARE
# 214655  2024-07-01   Costco  PERSONAL CARE   HAIR CARE
# 214659  2024-07-01   Costco  PERSONAL CARE   HAIR CARE
# 214662  2024-07-01   Costco  PERSONAL CARE   HAIR CARE
# ...            ...      ...            ...         ...
# 642758  2022-11-07      CVS  PERSONAL CARE   HAIR CARE
# 646780  2022-10-24   Amazon  PERSONAL CARE   HAIR CARE
# 656828  2022-10-03   Amazon  PERSONAL CARE   HAIR CARE
# 661227  2022-09-19      CVS  PERSONAL CARE   HAIR CARE
# 669513  2022-07-25      CVS  PERSONAL CARE   HAIR CARE
#
#                                               review_text  star_rating  \
# 214354  We have been using this duo for several years....          5.0
# 214364  I have a very sensitive scalp, tried hypoaller...          4.0
# 214655  We go through a lot of shampoo at our house an...          5.0
# 214659  Great product made my hair healthier and stronger          5.0
# 214662  Great shampoo and conditioner. Your hair will ...          5.0
# ...                                                   ...          ...
# 642758  Awesome stuff!! I bought CVS brand and love it...          5.0
# 646780                  smells better than headnshoulders          5.0
# 656828  This shampoo is fantastic, no more white speck...          5.0
# 661227  I use this on my granddaughters hair. I've tri...          5.0
# 669513  I love it ! It does a great job on my granddau...          5.0
#
#                                                     topic  brand_type
# 214354  Positive reviews for a makeup remover (undeter...  Competitor
# 214364  Positive reviews for a makeup remover (undeter...  Competitor
# 214655             Shopping for alternative hair products  Competitor
# 214659            Hair growth using conditioning products  Competitor
# 214662  Experiences with different hair products and b...  Competitor
# ...                                                   ...         ...
# 642758  Positive reviews for a makeup remover (undeter...  Competitor
# 646780                              Fragrances and scents  Competitor
# 656828  Positive reviews for a makeup remover (undeter...  Competitor
# 661227  Positive reviews for a makeup remover (undeter...  Competitor
# 669513  Positive reviews for a makeup remover (undeter...  Competitor
#
# [1591 rows x 10 columns]

# %%
# function for creating custom stopwords (from clorox code)
def create_custom_stopwords(df):

    unique_words = set()
    df['product_title'].drop_duplicates().str.split().apply(unique_words.update)
    df['brand'].drop_duplicates().str.split().apply(unique_words.update)
    unique_words = list(unique_words)

    custom_stopwords = unique_words + [word.lower() for word in unique_words] + [
        word.upper() for word in unique_words] + [word.capitalize() for word in unique_words]
    custom_stopwords = list(set(custom_stopwords))

    return custom_stopwords

# %%
# function for lemmetization
def preprocess_text(text):
        doc = nlp(text.lower())
        return " ".join([token.lemma_ for token in doc if not token.is_stop and not token.is_punct])

# create new cleaned review text 
df_sample['cleaned_review_text'] = df_sample['review_text'].apply(preprocess_text)
# Out:
# C:\Users\melod\AppData\Local\Temp\ipykernel_3428\2093435198.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sample['cleaned_review_text'] = df_sample['review_text'].apply(preprocess_text)

# %%
df_sample.head(5)
# Out:
#                    brand                                      product_title  \
# 214354            Nexxus  Nexxus Advanced Therappe Shampoo and Humectres...
# 214364            Nexxus  Nexxus Advanced Therappe Shampoo and Humectres...
# 214655  Head & Shoulders  Head & Shoulders Complete Scalp Care 2-in-1 Da...
# 214659            Nexxus  Nexxus Advanced Therappe Shampoo and Humectres...
# 214662            Nexxus  Nexxus Advanced Therappe Shampoo and Humectres...
#
#         proxy_date retailer       category subcategory  \
# 214354  2024-07-01   Costco  PERSONAL CARE   HAIR CARE
# 214364  2024-07-01   Costco  PERSONAL CARE   HAIR CARE
# 214655  2024-07-01   Costco  PERSONAL CARE   HAIR CARE
# 214659  2024-07-01   Costco  PERSONAL CARE   HAIR CARE
# 214662  2024-07-01   Costco  PERSONAL CARE   HAIR CARE
#
#                                               review_text  star_rating  \
# 214354  We have been using this duo for several years....          5.0
# 214364  I have a very sensitive scalp, tried hypoaller...          4.0
# 214655  We go through a lot of shampoo at our house an...          5.0
# 214659  Great product made my hair healthier and stronger          5.0
# 214662  Great shampoo and conditioner. Your hair will ...          5.0
#
#                                                     topic  brand_type  \
# 214354  Positive reviews for a makeup remover (undeter...  Competitor
# 214364  Positive reviews for a makeup remover (undeter...  Competitor
# 214655             Shopping for alternative hair products  Competitor
# 214659            Hair growth using conditioning products  Competitor
# 214662  Experiences with different hair products and b...  Competitor
#
#                                       cleaned_review_text
# 214354    duo year disappoint reduce size container price
# 214364  sensitive scalp try hypoallergenic cause actua...
# 214655             lot shampoo house size container great
# 214659                  great product hair healthy strong
# 214662        great shampoo conditioner hair feel amazing

# %%
def identify_topics(df, num_topics = 10, max_features=500):
    topic_list = []

    # get subcategory reviews
    subcategory_reviews = df['cleaned_review_text']

    # create stopwords (custom and default)
    custom_stopwords = create_custom_stopwords(df_sample)
    default_stopwords = list(CountVectorizer(
        stop_words="english").get_stop_words())
    all_stopwords = default_stopwords + custom_stopwords
 
    # create a term-document matrix
    vectorizer = TfidfVectorizer(stop_words=all_stopwords, max_features=max_features)
    tfidf_matrix = vectorizer.fit_transform(subcategory_reviews)

    # apply matrix factorization
    nmf_model = NMF(n_components = num_topics, random_state=42, solver='mu', beta_loss='kullback-leibler', max_iter=100)
    W = nmf_model.fit_transform(tfidf_matrix)
    H = nmf_model.components_
        
    # normalize and find dominant topic for each document
    doc_topic = normalize(W, norm='l1', axis=1)
    dominant_topic = doc_topic.argmax(axis=1)

    # add topic to list
    for topic_idx in dominant_topic:
        topic_words = " ".join([vectorizer.get_feature_names_out()[i] for i in H[topic_idx].argsort()[:-6:-1]])
        topic_list.append(topic_words)

    # add topic as new col to df
    df['NMF_topic'] = topic_list
    return df

# %%
df_with_topics = identify_topics(df_sample, num_topics=7)
# Out:
# c:\Users\melod\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:396: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['11oz', '12oz', '13', '14', '32oz', '33', '38', '5oz', '75oz', '8oz', 'anti', 'balance', 'balanced', 'control', 'defining', 'fl', 'itch', 'leave', 'loads', 'melatonin', 'multi', 'oz', 'palmer', 'peach', 'previously', 'repair', 'rose', 'scent', 'sense', 'solimo', 'spider', 'tasker', 'teal', 'types', 'use', 'vera', 'vinegar', 'water'] not in stop_words.
#   warnings.warn(
# c:\Users\melod\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:289: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(
# C:\Users\melod\AppData\Local\Temp\ipykernel_3428\3201180912.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NMF_topic'] = topic_list

# %%
df_with_topics.to_csv('reviews_nmf.csv', index=False)

# %%
df_with_topics['NMF_topic'].unique()
# Out:
# array(['good price quality product costco', 'work like brand use buy',
#        'great work price value wonderful',
#        'smell scent nice help recommend',
#        'product bottle review receive marketing',
#        'feel like clean leave year', 'soft leave dry use make'],
#       dtype=object)

# %%
df_with_topics['topic'].unique()
# Out:
# array(['Positive reviews for a makeup remover (undetermined topic)',
#        'Shopping for alternative hair products',
#        'Hair growth using conditioning products',
#        'Experiences with different hair products and brands',
#        'Skincare products and their effects on skin',
#        'Consumer complaints about changes in product ingredients and quality',
#        'Hair care and scent preferences', 'Reviews of water bottles',
#        'Skincare routines and product recommendations',
#        'Beauty product reviews and recommendations',
#        'Effective dandruff treatments',
#        'Customer satisfaction and experience', 'Good value for money',
#        'Long-time users of a product',
#        'Quality and Shipping Issues with Beauty Products',
#        'Hair growth and strengthening with oils',
#        'Packaging and shipping quality issues with beauty products',
#        'Favorite soaps and their reviews',
#        'Review of Maui Moisture hair products',
#        'Great deals on excellent products',
#        'Affordable and effective skincare options',
#        'Product reviews and satisfaction', 'Costco deals and prices',
#        'Shopping experiences on Amazon',
#        'Parent-approved products for daughters',
#        'Product review: Aveda Shampure shampoo and body wash',
#        'Skincare and beauty sheet masks',
#        'Best ways to remove facial gunk and blemishes',
#        'Scalp care products and their effectiveness',
#        'Walmart shopping experiences and product reviews',
#        'Sustainable and affordable beauty products',
#        'Reviews for pimple patches and their uses',
#        'Sustainability and eco-friendly practices in hair care products',
#        'Positive reviews for an excellent product',
#        'Comparison shopping and value for money',
#        'Hydrating face cream reviews', 'Best products for curly hair',
#        'Customer complaints and issues with online orders and pickup at Walgreens',
#        'Gift ideas for daughters', 'Benefits of scalp tingling products',
#        'Unpleasant odors in beauty products',
#        'Satisfactory arrival condition of products',
#        'Quality of lather and fragrance in soap products',
#        "Issues with Walgreens' website and rewards program",
#        'Customer reviews of a beauty product',
#        'Affordable and good quality products',
#        'Issues with product effectiveness and customer satisfaction',
#        'Product performance and user satisfaction',
#        'Effectiveness of acne treatments',
#        'Gentle and effective skincare products',
#        'Reviews of a creamy scented product',
#        'Product effectiveness and recommendations',
#        'Cost-effectiveness of Cetaphil products',
#        'Review of body wash with pleasant scent',
#        'Meeting expectations for online purchases',
#        'Effectiveness of skincare product and possible negative side effects',
#        'Performance and longevity of scented cosmetics',
#        'Customer satisfaction with product delivery',
#        'Unavailability of product in stores.',
#        'Value for Money in Consumer Products',
#        'Product reviews - body care items',
#        'Reviews of a Product not Working as Advertised',
#        'Customer satisfaction with delivery service',
#        'Negative reactions to Cerave products',
#        'Missing or incorrect items in order',
#        'Razors and shaving products',
#        'Comparison of Skincare Brands and Their Effectiveness',
#        'Personal reviews and experiences with skincare products',
#        'Product review: Gentle vs Harsh Chair',
#        'Pricing changes and customer satisfaction',
#        'Fast-absorbing facial moisturizers',
#        'Affordable beauty and skincare products',
#        'Skincare for Men with Dry and Sensitive Skin',
#        'Positive reviews for a product',
#        'Scent preferences and reviews for a product targeted towards teenage boys',
#        'Beard grooming and maintenance tips and products',
#        'Adverse skin reactions to a product',
#        'Headaches triggered by strong smells or certain products',
#        'Negative effects of certain hair products',
#        'Scent and longevity of personal care products',
#        'Reviews on No7 Jeunesse Serum',
#        "Mixed reviews on a product's effectiveness",
#        'Customer reviews of Topbox products',
#        'Positive scent experiences with Jerkins lotion',
#        'Value for money in scented products',
#        'Gratitude and Appreciation', 'Scalp care and tingling sensations',
#        'Positive reviews of a product',
#        'Product satisfaction and quality',
#        'Citrus scented washing products',
#        'Receiving compliments on scent',
#        'Sensitive skin body wash for men',
#        'Skincare recommendations and experiences from dermatologists and users',
#        'Reviewing a light weight beauty product', 'Precision of orders',
#        'Positive consumer experiences and influencer recommendations',
#        "Long-term users' positive reviews", 'Brand loyalty',
#        'Loyalty and longevity for a product',
#        'Raving reviews for skin care products',
#        'Product quality and pricing comparison',
#        'Daughter-approved face wash',
#        'Relaxation and Stress Relief through Using Lavender Products',
#        'Hydration and Moisturization with Neutrogena Hydro Boost Cream',
#        'Problems with product formula and packaging',
#        'Quality and effectiveness of beauty products',
#        'Consistency and effectiveness of body lotions',
#        'Effectiveness of product after weeks of use',
#        'Fragrances and scents', 'Price and affordability of Dove soap',
#        'Personal experiences and recommendations for beauty products',
#        'Reviewing skin products and their effectiveness',
#        'Fragrance-free options in skincare',
#        'Tingle and plump face serums',
#        'Treating skin conditions with sensitive skin and skin allergies',
#        'Moisture lotion reviews and recommendations',
#        'Sleep aid and relaxation products',
#        'Scent and residue of lotions and lip balms',
#        'Positive reviews for a lotion product',
#        'Product reviews and customer satisfaction',
#        'Product quality and packaging issues',
#        'Customer reviews for a skin treatment product',
#        'Negative reactions to facial products',
#        'Reviews of twistable balms',
#        'Renewing Moisturizing Product Reviews and Usage Habits',
#        'Confusing and ineffective skin care products',
#        'Review of Neutrogena products',
#        'Scent preferences and experiences with grooming products',
#        'Quality and cost comparison of high-end products',
#        'Eczema and sensitive skin care',
#        'Finding cheaper deals at stores',
#        'Incorrect or unexpected product received',
#        'Personal care products and their features',
#        'Malfunctioning product pump',
#        'Product reviews: Biore Charcoal Cleanser',
#        'Affordable and Quality Skincare Products',
#        'Dissatisfaction with formula change in personal care product',
#        'Personal care and hygiene products reviews',
#        'Expectation and size discrepancies',
#        'Issues with recent reformulation of product scent',
#        'Product packaging and delivery experience',
#        'Pleasant and effective scents for the home and personal use',
#        'Skincare products and their effectiveness',
#        'Scent and moisturizing properties of lotion',
#        'Performance and longevity of soap lather',
#        'Expiration date issues with products',
#        'Benefits of using Olay lotion on sensitive skin',
#        'Packaging issues with a specific product',
#        'Product size and effectiveness reviews',
#        'Customer reviews and satisfaction with a product',
#        'Positive reviews for beauty products',
#        'Opinions on a particular skincare product',
#        'Lather and scent of natural soaps',
#        'Positive reviews for a product from a son or husband',
#        'Results and satisfaction with new beauty product',
#        'Customer service and order fulfillment issues',
#        'Eucalyptus-based personal care products',
#        'Equate beauty products and their affordability and effectiveness compared to higher priced brands',
#        'Hair conditioners and their effectiveness',
#        'Pacha Soap products and customer experiences',
#        'Cooling sensation beauty products',
#        'Packaging and product quality issues',
#        'Dry skin treatment and recommendations',
#        "Issues with a product's quality and smell",
#        'Critiques on product ingredients and effectiveness',
#        'Customer satisfaction and use of products',
#        'Makeup removal product review',
#        'Scent and effectiveness of body wash products',
#        'Game-changing dry skin products',
#        'Personal testimonials on a successful product',
#        'Fast and affordable shipping options'], dtype=object)
